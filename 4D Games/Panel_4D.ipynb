# %% [markdown]
# # [Intro to Data Structures](https://pandas.pydata.org/pandas-docs/version/0.17.0/dsintro.html#series)

# %% [markdown]
# # [Series](https://pandas.pydata.org/pandas-docs/version/0.17.0/dsintro.html#series)

# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series(np.random.randn(5), index=['a', 'b', 'c', 'd', 'e'])
s
# Out:
# a   -0.179276
# b    1.004520
# c   -1.344587
# d   -1.699669
# e   -1.074553
# dtype: float64

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
pd.Series(np.random.randn(5))
# Out:
# 0   -0.787171
# 1    0.068485
# 2   -0.210245
# 3    1.436049
# 4    0.613123
# dtype: float64

# %%
d = {'a' : 0., 'b' : 1., 'c' : 2.}
pd.Series(d)
# Out:
# a    0.0
# b    1.0
# c    2.0
# dtype: float64

# %%
pd.Series(d, index=['b', 'c', 'd', 'a'])
# Out:
# b    1.0
# c    2.0
# d    NaN
# a    0.0
# dtype: float64

# %% [markdown]
# From scalar value If data is a scalar value, an index must be provided. The value will be repeated to match the length of index

# %%
pd.Series(5, index=['a', 'b', 'c', 'd', 'e'])
# Out:
# a    5
# b    5
# c    5
# d    5
# e    5
# dtype: int64

# %%
s
# Out:
# a   -0.179276
# b    1.004520
# c   -1.344587
# d   -1.699669
# e   -1.074553
# dtype: float64

# %%
s[0]
# Out:
# -0.1792759755846804

# %%
s[:3]
# Out:
# a   -0.179276
# b    1.004520
# c   -1.344587
# dtype: float64

# %%
s[s > s.median()]
# Out:
# a   -0.179276
# b    1.004520
# dtype: float64

# %%
s[[4,3,1]]
# Out:
# e   -1.074553
# d   -1.699669
# b    1.004520
# dtype: float64

# %%
np.exp(s)
# Out:
# a    0.835875
# b    2.730596
# c    0.260647
# d    0.182744
# e    0.341450
# dtype: float64

# %%
s['a'] == s[[0,]]
# Out:
# a    True
# dtype: bool

# %%
s['a']
# Out:
# -0.1792759755846804

# %%
s['e']
# Out:
# -1.0745530446432012

# %%
s
# Out:
# a   -0.179276
# b    1.004520
# c   -1.344587
# d   -1.699669
# e   -1.074553
# dtype: float64

# %%
'e' in s
# Out:
# True

# %%
'f' in s
# Out:
# False

# %%
s.get('f', np.nan)
# Out:
# nan

# %%
s+s
# Out:
# a   -0.358552
# b    2.009040
# c   -2.689173
# d   -3.399339
# e   -2.149106
# dtype: float64

# %%
s*2
# Out:
# a   -0.358552
# b    2.009040
# c   -2.689173
# d   -3.399339
# e   -2.149106
# dtype: float64

# %%
np.exp(s)
# Out:
# a    0.835875
# b    2.730596
# c    0.260647
# d    0.182744
# e    0.341450
# dtype: float64

# %%
s[1:]
# Out:
# b    1.004520
# c   -1.344587
# d   -1.699669
# e   -1.074553
# dtype: float64

# %%
s[:-1]
# Out:
# a   -0.179276
# b    1.004520
# c   -1.344587
# d   -1.699669
# dtype: float64

# %%
s[1:] + s[:-1]
# Out:
# a         NaN
# b    2.009040
# c   -2.689173
# d   -3.399339
# e         NaN
# dtype: float64

# %%
s = pd.Series(np.random.randn(5), name='something')
s
# Out:
# 0   -0.769761
# 1   -0.779107
# 2   -0.745004
# 3   -0.567864
# 4    0.539211
# Name: something, dtype: float64

# %%
s.name
# Out:
# 'something'

# %% [markdown]
# # [DataFrame](https://pandas.pydata.org/pandas-docs/version/0.17.0/dsintro.html#dataframe)

# %%
d = {'one' : pd.Series([1., 2., 3.], index=['a', 'b', 'c']), 
     'two' : pd.Series([1., 2., 3., 4.], index=['a', 'b', 'c', 'd'])}

df = pd.DataFrame(d)
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
pd.DataFrame(d, index=['d', 'b', 'a'])
# Out:
#    one  two
# d  NaN  4.0
# b  2.0  2.0
# a  1.0  1.0

# %%
pd.DataFrame(d, index=['d', 'b', 'a'], columns=['two', 'three'])
# Out:
#    two three
# d  4.0   NaN
# b  2.0   NaN
# a  1.0   NaN

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
df.columns
# Out:
# Index(['one', 'two'], dtype='object')

# %%
d = {'one' : [1., 2., 3., 4.],
     'two' : [4., 3., 2., 1.]}

pd.DataFrame(d)
# Out:
#    one  two
# 0  1.0  4.0
# 1  2.0  3.0
# 2  3.0  2.0
# 3  4.0  1.0

# %%
pd.DataFrame(d, index=['a', 'b', 'c', 'd'])
# Out:
#    one  two
# a  1.0  4.0
# b  2.0  3.0
# c  3.0  2.0
# d  4.0  1.0

# %%
data = np.zeros((2,), dtype=[('A', 'i4'), ('B', 'f4'), ('C', 'a10')])
data
# Out:
# array([(0, 0., b''), (0, 0., b'')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
data[:] = [(1, 2., 'Hello'), (2, 3., "World")]
data
# Out:
# array([(1, 2., b'Hello'), (2, 3., b'World')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
pd.DataFrame(data)
# Out:
#    A    B         C
# 0  1  2.0  b'Hello'
# 1  2  3.0  b'World'

# %%
pd.DataFrame(data, index=['first', 'second'])
# Out:
#         A    B         C
# first   1  2.0  b'Hello'
# second  2  3.0  b'World'

# %%
pd.DataFrame(data, columns=['C', 'A', 'B'])
# Out:
#           C  A    B
# 0  b'Hello'  1  2.0
# 1  b'World'  2  3.0

# %%
pd.DataFrame(data, index=['first', 'second'], columns=['C', 'A', 'B', 'D'])
# Out:
#                C  A    B    D
# first   b'Hello'  1  2.0  NaN
# second  b'World'  2  3.0  NaN

# %%
data2 = [{'a' : 1, 'b' : 2}, {'a' : 5, 'b' : 10, 'c' : 20}]

pd.DataFrame(data2)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %%
pd.DataFrame(data2, index=['first', 'second'])
# Out:
#         a   b     c
# first   1   2   NaN
# second  5  10  20.0

# %%
pd.DataFrame(data2, columns=['a', 'b'])
# Out:
#    a   b
# 0  1   2
# 1  5  10

# %%
pd.DataFrame(
  {('a', 'b'): {('A', 'B'): 1, ('A', 'C'): 2},
  ('a', 'a'): {('A', 'C'): 3, ('A', 'B'): 4},
  ('a', 'c'): {('A', 'B'): 5, ('A', 'C'): 6},
  ('b', 'a'): {('A', 'C'): 7, ('A', 'B'): 8},
  ('b', 'b'): {('A', 'D'): 9, ('A', 'B'): 10}}
)
# Out:
#        a              b
#        b    a    c    a     b
# A B  1.0  4.0  5.0  8.0  10.0
#   C  2.0  3.0  6.0  7.0   NaN
#   D  NaN  NaN  NaN  NaN   9.0

# %%
data
# Out:
# array([(1, 2., b'Hello'), (2, 3., b'World')],
#       dtype=[('A', '<i4'), ('B', '<f4'), ('C', 'S10')])

# %%
pd.DataFrame.from_records(data, index='C')
# Out:
#           A    B
# C
# b'Hello'  1  2.0
# b'World'  2  3.0

# %%
# https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.DataFrame.from_items.html
pd.DataFrame.from_dict([('A', [1, 2, 3]), ('B', [4, 5, 6])])
# Out:
#    0          1
# 0  A  [1, 2, 3]
# 1  B  [4, 5, 6]

# %%
# pd.DataFrame.from_items([('A', [1, 2, 3]), ('B', [4, 5, 6])], orient='index', columns=['one', 'two', 'three'])

# %%
# https://pandas.pydata.org/pandas-docs/version/0.17.0/dsintro.html#column-selection-addition-deletion
df
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %%
df['one']
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# Name: one, dtype: float64

# %%
df['three'] = df['one'] * df['two']
df['flag'] = df['one'] > 2
df
# Out:
#    one  two  three   flag
# a  1.0  1.0    1.0  False
# b  2.0  2.0    4.0  False
# c  3.0  3.0    9.0   True
# d  NaN  4.0    NaN  False

# %%
del df['two']
three = df.pop('three')
df
# Out:
#    one   flag
# a  1.0  False
# b  2.0  False
# c  3.0   True
# d  NaN  False

# %%
three
# Out:
# a    1.0
# b    4.0
# c    9.0
# d    NaN
# Name: three, dtype: float64

# %%
df['foo'] = 'bar'
df
# Out:
#    one   flag  foo
# a  1.0  False  bar
# b  2.0  False  bar
# c  3.0   True  bar
# d  NaN  False  bar

# %%
df['one_trunc'] = df['one'][:2]
df
# Out:
#    one   flag  foo  one_trunc
# a  1.0  False  bar        1.0
# b  2.0  False  bar        2.0
# c  3.0   True  bar        NaN
# d  NaN  False  bar        NaN

# %%
df.insert(1, 'bar', df['one'])
df
# Out:
#    one  bar   flag  foo  one_trunc
# a  1.0  1.0  False  bar        1.0
# b  2.0  2.0  False  bar        2.0
# c  3.0  3.0   True  bar        NaN
# d  NaN  NaN  False  bar        NaN

# %%
iris = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# assign always returns a copy of the data, leaving the original DataFrame untouched.
iris.assign(sepal_ratio = iris['sepal_width'] / iris['sepal_length']).head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  sepal_ratio
# 0           5.1          3.5           1.4          0.2  setosa     0.686275
# 1           4.9          3.0           1.4          0.2  setosa     0.612245
# 2           4.7          3.2           1.3          0.2  setosa     0.680851
# 3           4.6          3.1           1.5          0.2  setosa     0.673913
# 4           5.0          3.6           1.4          0.2  setosa     0.720000

# %%
iris.assign(sepal_ratio = lambda x: (x['sepal_width'] / x['sepal_length'])).tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species  \
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
#      sepal_ratio
# 145     0.447761
# 146     0.396825
# 147     0.461538
# 148     0.548387
# 149     0.508475

# %%
# iris.query('sepal_length > 5.0').assign(sepal_ratio = lambda x: x.sepal_width / x.sepal_length, sepal_ratio = lambda x: x.petal_width / x.petal_length).plot(kind='scatter', x='sepal_ratio', y='petal_ratio')

# %% [markdown]
# ![ss](https://pandas.pydata.org/pandas-docs/version/0.17.0/_images/basics_assign.png)

# %%
# df.assign(C = lambda x: x['A'] + x['B']).assign(D = lambda x: x['A'] + x['C'])

# %% [markdown]
# <table border="1" class="docutils">
# <colgroup>
# <col width="50%">
# <col width="33%">
# <col width="17%">
# </colgroup>
# <thead valign="bottom">
# <tr class="row-odd"><th class="head">Operation</th>
# <th class="head">Syntax</th>
# <th class="head">Result</th>
# </tr>
# </thead>
# <tbody valign="top">
# <tr class="row-even"><td>Select column</td>
# <td><tt class="docutils literal"><span class="pre">df[col]</span></tt></td>
# <td>Series</td>
# </tr>
# <tr class="row-odd"><td>Select row by label</td>
# <td><tt class="docutils literal"><span class="pre">df.loc[label]</span></tt></td>
# <td>Series</td>
# </tr>
# <tr class="row-even"><td>Select row by integer location</td>
# <td><tt class="docutils literal"><span class="pre">df.iloc[loc]</span></tt></td>
# <td>Series</td>
# </tr>
# <tr class="row-odd"><td>Slice rows</td>
# <td><tt class="docutils literal"><span class="pre">df[5:10]</span></tt></td>
# <td>DataFrame</td>
# </tr>
# <tr class="row-even"><td>Select rows by boolean vector</td>
# <td><tt class="docutils literal"><span class="pre">df[bool_vec]</span></tt></td>
# <td>DataFrame</td>
# </tr>
# </tbody>
# </table>

# %%
df
# Out:
#    one  bar   flag  foo  one_trunc
# a  1.0  1.0  False  bar        1.0
# b  2.0  2.0  False  bar        2.0
# c  3.0  3.0   True  bar        NaN
# d  NaN  NaN  False  bar        NaN

# %%
df.loc['b']
# Out:
# one            2.0
# bar            2.0
# flag         False
# foo            bar
# one_trunc      2.0
# Name: b, dtype: object

# %%
df.iloc[2]
# Out:
# one           3.0
# bar           3.0
# flag         True
# foo           bar
# one_trunc     NaN
# Name: c, dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4), columns=['A', 'B', 'C', 'D'])
df
# Out:
#           A         B         C         D
# 0  0.400039  0.617729  1.374557 -0.508661
# 1  0.113959  0.190525 -1.348401 -0.824795
# 2 -0.669504  0.378567  0.163880  0.580276
# 3 -0.793900  0.350789  0.002983 -0.314900
# 4 -0.766962  0.388381 -0.527093 -0.451364
# 5  1.106483  1.522864  0.466429 -0.966616
# 6 -0.218352  2.149964 -1.493201 -1.222822
# 7  1.351323 -0.201325  0.321702  0.519737
# 8  0.992758 -0.284728 -0.880578 -0.259262
# 9 -1.510088 -0.669669  0.183103  0.704404

# %%
df2 = pd.DataFrame(np.random.randn(7, 3), columns=['A', 'B', 'C'])
df + df2
# Out:
#           A         B         C   D
# 0 -1.573819  1.811805  1.232235 NaN
# 1 -0.399080  1.770911 -0.761849 NaN
# 2  0.572250  0.446738  1.618381 NaN
# 3 -1.886133  0.362286 -1.015956 NaN
# 4 -1.293507  2.771374 -0.324106 NaN
# 5  1.521770 -0.108381  0.717830 NaN
# 6 -1.515903  1.797626 -3.356030 NaN
# 7       NaN       NaN       NaN NaN
# 8       NaN       NaN       NaN NaN
# 9       NaN       NaN       NaN NaN

# %%
df.iloc[0]
# Out:
# A    0.400039
# B    0.617729
# C    1.374557
# D   -0.508661
# Name: 0, dtype: float64

# %%
df - df.iloc[0]
# Out:
#           A         B         C         D
# 0  0.000000  0.000000  0.000000  0.000000
# 1 -0.286080 -0.427204 -2.722957 -0.316134
# 2 -1.069543 -0.239163 -1.210677  1.088937
# 3 -1.193939 -0.266940 -1.371574  0.193761
# 4 -1.167001 -0.229348 -1.901649  0.057297
# 5  0.706444  0.905135 -0.908128 -0.457955
# 6 -0.618391  1.532234 -2.867758 -0.714161
# 7  0.951284 -0.819054 -1.052855  1.028398
# 8  0.592719 -0.902457 -2.255135  0.249399
# 9 -1.910127 -1.287398 -1.191454  1.213065

# %%
index = pd.date_range('1/1/2000', periods=36)
index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14', '2000-01-15', '2000-01-16',
#                '2000-01-17', '2000-01-18', '2000-01-19', '2000-01-20',
#                '2000-01-21', '2000-01-22', '2000-01-23', '2000-01-24',
#                '2000-01-25', '2000-01-26', '2000-01-27', '2000-01-28',
#                '2000-01-29', '2000-01-30', '2000-01-31', '2000-02-01',
#                '2000-02-02', '2000-02-03', '2000-02-04', '2000-02-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(8, 3),
                  index = pd.date_range('1/1/2000', periods=8),
                  columns = list('ABC'),
                  )
df
# Out:
#                    A         B         C
# 2000-01-01  0.142980  0.298441  0.376236
# 2000-01-02  1.414891 -0.774851  0.875617
# 2000-01-03 -2.570544  0.232319 -1.237126
# 2000-01-04  0.604815  0.533303 -0.162483
# 2000-01-05 -1.872393  0.100759  0.186198
# 2000-01-06  0.058534 -1.213358  0.733581
# 2000-01-07 -2.492105 -0.115060  1.412039
# 2000-01-08 -0.306748 -0.942421 -1.668813

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
# df.sub(df['A'], axis=1) # This is preferred way to replicate this behavior.
df - df['A'] # This is now deprecated and will be removed in a future release.
# Out:
#             2000-01-01 00:00:00  2000-01-02 00:00:00  2000-01-03 00:00:00  \
# 2000-01-01                  NaN                  NaN                  NaN
# 2000-01-02                  NaN                  NaN                  NaN
# 2000-01-03                  NaN                  NaN                  NaN
# 2000-01-04                  NaN                  NaN                  NaN
# 2000-01-05                  NaN                  NaN                  NaN
# 2000-01-06                  NaN                  NaN                  NaN
# 2000-01-07                  NaN                  NaN                  NaN
# 2000-01-08                  NaN                  NaN                  NaN
#
#             2000-01-04 00:00:00  2000-01-05 00:00:00  2000-01-06 00:00:00  \
# 2000-01-01                  NaN                  NaN                  NaN
# 2000-01-02                  NaN                  NaN                  NaN
# 2000-01-03                  NaN                  NaN                  NaN
# 2000-01-04                  NaN                  NaN                  NaN
# 2000-01-05                  NaN                  NaN                  NaN
# 2000-01-06                  NaN                  NaN                  NaN
# 2000-01-07                  NaN                  NaN                  NaN
# 2000-01-08                  NaN                  NaN                  NaN
#
#             2000-01-07 00:00:00  2000-01-08 00:00:00   A   B   C
# 2000-01-01                  NaN                  NaN NaN NaN NaN
# 2000-01-02                  NaN                  NaN NaN NaN NaN
# 2000-01-03                  NaN                  NaN NaN NaN NaN
# 2000-01-04                  NaN                  NaN NaN NaN NaN
# 2000-01-05                  NaN                  NaN NaN NaN NaN
# 2000-01-06                  NaN                  NaN NaN NaN NaN
# 2000-01-07                  NaN                  NaN NaN NaN NaN
# 2000-01-08                  NaN                  NaN NaN NaN NaN

# %%
dfA = df.sub(df['A'], axis=0)
dfA
# Out:
#               A         B         C
# 2000-01-01  0.0  0.155461  0.233256
# 2000-01-02  0.0 -2.189741 -0.539274
# 2000-01-03  0.0  2.802863  1.333418
# 2000-01-04  0.0 -0.071512 -0.767297
# 2000-01-05  0.0  1.973152  2.058591
# 2000-01-06  0.0 -1.271892  0.675047
# 2000-01-07  0.0  2.377045  3.904144
# 2000-01-08  0.0 -0.635673 -1.362064

# %%
dfA * 5 + 2
# Out:
#               A          B          C
# 2000-01-01  2.0   2.777304   3.166280
# 2000-01-02  2.0  -8.948707  -0.696370
# 2000-01-03  2.0  16.014314   8.667088
# 2000-01-04  2.0   1.642440  -1.836487
# 2000-01-05  2.0  11.865761  12.292956
# 2000-01-06  2.0  -4.359460   5.375233
# 2000-01-07  2.0  13.885225  21.520721
# 2000-01-08  2.0  -1.178363  -4.810322

# %%
1/dfA
# Out:
#               A          B         C
# 2000-01-01  inf   6.432486  4.287136
# 2000-01-02  inf  -0.456675 -1.854345
# 2000-01-03  inf   0.356778  0.749953
# 2000-01-04  inf -13.983674 -1.303276
# 2000-01-05  inf   0.506803  0.485769
# 2000-01-06  inf  -0.786230  1.481379
# 2000-01-07  inf   0.420690  0.256138
# 2000-01-08  inf  -1.573137 -0.734180

# %%
dfA ** 4
# Out:
#               A          B           C
# 2000-01-01  0.0   0.000584    0.002960
# 2000-01-02  0.0  22.991710    0.084574
# 2000-01-03  0.0  61.717355    3.161292
# 2000-01-04  0.0   0.000026    0.346621
# 2000-01-05  0.0  15.158013   17.958926
# 2000-01-06  0.0   2.616984    0.207651
# 2000-01-07  0.0  31.926374  232.329007
# 2000-01-08  0.0   0.163280    3.441839

# %%
df1 = pd.DataFrame({'a' : [1, 0, 1], 'b' : [0, 1, 1]}, dtype=bool)
df1
# Out:
#        a      b
# 0   True  False
# 1  False   True
# 2   True   True

# %%
-df1
# Out:
#        a      b
# 0  False   True
# 1   True  False
# 2  False  False

# %%
df2 = pd.DataFrame({'a' : [0, 1, 1], 'b' : [1, 1, 0]}, dtype=bool)
df2
# Out:
#        a      b
# 0  False   True
# 1   True   True
# 2   True  False

# %%
df1 & df2
# Out:
#        a      b
# 0  False  False
# 1  False   True
# 2   True  False

# %%
df1 | df2
# Out:
#       a     b
# 0  True  True
# 1  True  True
# 2  True  True

# %%
df1 ^ df2
# Out:
#        a      b
# 0   True   True
# 1   True  False
# 2  False   True

# %%
# https://pandas.pydata.org/pandas-docs/version/0.17.0/dsintro.html#transposing
